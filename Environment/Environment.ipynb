# %%
# %pip install tensorflow
# %pip install keras
# %pip install scikit-learn
# %pip install fastai
# %pip install torch
# %pip install zipfile
# %pip install matplotlib
# %pip install pandas
# %pip install numpy
# %pip install seaborn
# %pip install os
# %pip install urllib.request
# %pip install tkinter
# %pip install tarfile
# %pip install xgboost

# %%
import os
import urllib.request
import tarfile
import zipfile
from tkinter import Tk, filedialog
import pandas
import numpy
import matplotlib
import seaborn
import zipfile
import sklearn
import xgboost as xgb
import tensorflow as tf
import keras
import fastai
import torch
#Print the versions of the libraries
print("TensorFlow version:", tf.__version__)
print("Keras version:", tf.keras.__version__)
print("Scikit-learn version:", sklearn.__version__)
print("Fastai version:", fastai.__version__)
print("Torch version:", torch.__version__)
print("Zipfile: Standard library module (Python built-in)")
print("Matplotlib version:", matplotlib.__version__)
print("Pandas version:", pandas.__version__)
print("NumPy version:", numpy.__version__)
print("Seaborn version:", seaborn.__version__)
print("OS: Standard library module (Python built-in)")
print("Urllib.request: Standard library module (Python built-in)")
print("Tkinter version:", Tk().tk.call("info", "patchlevel"))
print("Tarfile: Standard library module (Python built-in)")
print("XGBoost version:", xgb.__version__)
# Out:
# TensorFlow version: 2.19.0
# Keras version: 3.9.1
# Scikit-learn version: 1.6.1
# Fastai version: 2.7.19
# Torch version: 2.6.0+cpu
# Zipfile: Standard library module (Python built-in)
# Matplotlib version: 3.10.0
# Pandas version: 2.2.3
# NumPy version: 2.2.2
# Seaborn version: 0.13.2
# OS: Standard library module (Python built-in)
# Urllib.request: Standard library module (Python built-in)
# Tkinter version: 8.6.13
# Tarfile: Standard library module (Python built-in)
# XGBoost version: 3.0.0
